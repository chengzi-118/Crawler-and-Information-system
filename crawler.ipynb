# %%
import requests
from bs4 import BeautifulSoup

url = "https://wapi.kuwo.cn/api/www/artist/artistInfo?category=1&prefix=&pn=2&rn=60&httpsStatus=1&reqId=283aacd0-52a9-11f0-8edc-656bca46e1b4&plat=web_www&from="
headers = {
    "Accept": "application/json, text/plain,",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Connection": "keep-alive",
    "Origin": "https://www.kuwo.cn",
    "Referer": "https://www.kuwo.cn/",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "sec-ch-ua": '"Google Chrome";v="137", "Chromium";v="137", "Not/A)Brand";v="24"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows"}
response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, features = "lxml")
# Out:
# <html>
#  <body>
#   <p>
# ...

# %%
import re

data = re.findall(r'\[.*\]', soup.string)[0]
singers = re.findall(r"\{.*?\}", data)
for x in singers:
    print(x)
# Out:
# {"artistFans":14712,"albumNum":25,"mvNum":4,"pic":"https://img4.kuwo.cn/star/starheads/300/s4s7/9/2073266028.jpg","musicNum":93,"pic120":"https://img4.kuwo.cn/star/starheads/120/s4s7/9/2073266028.jpg","isStar":0,"content_type":"0","aartist":"","name":"张紫豪","pic70":"https://img4.kuwo.cn/star/starheads/70/s4s7/9/2073266028.jpg","id":2544935,"pic300":"https://img4.kuwo.cn/star/starheads/300/s4s7/9/2073266028.jpg"}
# {"artistFans":49908,"albumNum":112,"mvNum":125,"pic":"https://img3.kuwo.cn/star/starheads/300/19/84/1010990435.jpg","musicNum":2281,"pic120":"https://img3.kuwo.cn/star/starheads/120/19/84/1010990435.jpg","isStar":0,"content_type":"0","aartist":"George Lam","name":"林子祥","pic70":"https://img3.kuwo.cn/star/starheads/70/19/84/1010990435.jpg","id":646,"pic300":"https://img3.kuwo.cn/star/starheads/300/19/84/1010990435.jpg"}
# ...
